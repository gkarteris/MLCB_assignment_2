# %% [markdown]
# # Machine Learning in Computational Biology - Assignment #2 - Spring 2026

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
import pandas as pd

project_dir = Path.cwd().parent
utils_dir = project_dir / 'src'

if str(utils_dir) not in sys.path:
    sys.path.append(str(utils_dir))

import functions
import visualization_functions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Task 1.1 - Dataset Overview and Descriptive Statistics

# %%
dataset_raw = functions.load_data('students_dataset.csv')

# %%
print("Dataset Overview")
print(dataset_raw.info())
print("\nMissing Values")
print(dataset_raw.isnull().sum())
print("\nDescriptive Statistics")
display(dataset_raw.describe())
# Out:
# Dataset Overview
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       242 non-null    float64
#  1   sex       242 non-null    float64
#  2   cp        242 non-null    float64
#  3   trestbps  242 non-null    float64
#  4   chol      242 non-null    float64
#  5   fbs       242 non-null    float64
#  6   restecg   242 non-null    float64
#  7   thalach   242 non-null    float64
#  8   exang     242 non-null    float64
#  9   oldpeak   242 non-null    float64
#  10  slope     242 non-null    float64
#  11  ca        241 non-null    float64
#  12  thal      241 non-null    float64
#  13  num       242 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 26.6 KB
# None
#
# Missing Values
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# ...

# %%
print("Data summary for 'development_data.csv':")
visualization_functions.summarize_dataset(dataset_raw, title="UCI Heart Disease Dataset (Cleveland subset)", dim1_comment="features", dim2_comment="samples")
# Out:
# Data summary for 'development_data.csv':

# %% [markdown]
# ### Task 1.2 - Feature Assessment and Visualization

# %%
visualization_functions.plot_feature_distributions(dataset_raw)
visualization_functions.plot_correlation_heatmap(dataset_raw)
visualization_functions.plot_pca_separability(dataset_raw)

# %%
visualization_functions.plot_kernel_pca(dataset_raw)
